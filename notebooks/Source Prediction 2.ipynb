# %%
import pandas as pd

def load_data():
    article_table = pd.read_json("../data/cache/testsentimentanalysis_partial/documents.json")
    return article_table

# %%
articles = load_data()
articles
# Out:
#         source                                               text
# 0     Atlantic    Last fall, Anne Donahue at The Guardian coin...
# 1     Atlantic  , I want to receive updates from partners and ...
# 2     Atlantic  , I want to receive updates from partners and ...
# 3     Atlantic  , I want to receive updates from partners and ...
# 4     Atlantic  For the past eight years, Americans have been ...
# 5     Atlantic  As a Daily Show correspondent and host of The ...
# 6     Atlantic             For us to continue writing great st...
# 7     Atlantic  Labor’s share, the measure that illustrates ho...
# 8     Atlantic  The answer to all these questions may have som...
# 9     Atlantic  , I want to receive updates from partners and ...
# 10    Atlantic  It didn’t work. Trump quarreled with Mayor Ed ...
# 11    Atlantic  The women of Liberia, who had borne the brunt ...
# 12    Atlantic  , I want to receive updates from partners and ...
# ...

# %%
articles.iloc[4979].text
# Out:
# ', I want to receive updates from partners and sponsors. Twenty years ago, Kobe Bryant made his NBA debut as an    fresh out of high school. He went scoreless in the game. Tonight, the   champion, third   leading scorer, and     will play the last game of his career in what is sure to be an emotional sendoff to the Los Angeles Lakers great. Bryant, known by the moniker he gave himself, the Black Mamba, and the Lakers face off against the Utah Jazz at home to end the season. He announced his retirement in a poem last November, in part writing,  My heart can take the pounding   My mind can handle the grind   But my body knows it s time to say goodbye. ? Indeed, the last few seasons have been rocky for the Bryant, and the Lakers for that matter. Los Angeles is missing the playoffs for the third consecutive season, something that seemed unheard of during the Phil Jackson years of coaching from 1999 to 2004 and from 2005 to 2011. In the team s   history, the Lakers have only missed the pl
# ...

# %% [markdown]
# ## TFIDF predictions

# %%
import pandas as pd
#with open("../data/cache/testsentimentanalysis_partial/tfidif.json") as in_file:
    #tfidf_vectors = json.load(in_file)
tfidf_df = pd.read_json("../data/cache/testsentimentanalysis_partial/tfidif.json")
tfidf_df
# Out:
#           0         1         2         3         4         5         6     \
# 0     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     0.000000  0.000000  0.000000  0.022030  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4     0.008421  0.009245  0.010746  0.000000  0.000000  0.000000  0.000000
# 5     0.000000  0.000000  0.000000  0.000000  0.021759  0.000000  0.000000
# 6     0.000000  0.000000  0.000000  0.035289  0.000000  0.000000  0.000000
# 7     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8     0.018264  0.000000  0.011653  0.000000  0.013011  0.000000  0.000000
# 9     0.000000  0.014562  0.000000  0.018309  0.000000  0.000000  0.000000
# 10    0.000000  0.000000  0.030385  0.000000  0.000000  0.000000  0.000000
# ...

# %%
from sklearn.model_selection import train_test_split

X = tfidf_df
y = articles.source

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
